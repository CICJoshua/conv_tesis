# %%
from parts.dataFrame import DataFrame
from parts.statsDesc import StatsDesc
import os
import matplotlib.pyplot as plt

# %%
def main():
    __dirname = os.getcwd()
    __list_files = os.listdir(os.path.join(__dirname, "datos"))
    __file = [file for file in __list_files if "json" in file][0]
    print(__file)
    __path = f"{__dirname}\\datos\\{__file}"
    stat_desc = StatsDesc(__path)
    return stat_desc.getDataFrame()

# %%
main()
# Out:
# pacientes.json
# d:\tesis\datos\pacientes.json
# DatetimeIndex(['2014-07-23 10:38:47', '2015-02-11 10:47:05',
#                '2015-03-11 09:58:04', '2014-12-24 10:19:57',
#                '2015-07-22 10:09:20', '2015-09-23 09:38:20',
#                '2015-12-09 09:07:30', '2016-06-15 08:43:35',
#                '2015-09-23 09:01:24', '2015-11-18 09:15:05',
#                ...
#                '2014-09-08 09:52:56', '2019-01-30 14:29:48',
#                '2014-09-19 00:00:00', '2014-09-24 00:00:00',
#                '2014-09-25 00:00:00', '2014-09-29 00:00:00',
#                '2014-10-03 00:00:00', '2014-10-03 11:23:32',
#                '2014-10-08 00:00:00', '2014-10-09 00:00:00'],
#               dtype='datetime64[ns]', name='fecha', length=85344, freq=None)
# 100%|██████████| 85344/85344 [00:00<00:00, 263409.25it/s]
# 26     12098
# 0      11431
# 141     5227
# 140     4814
# 46      3863
# Name: freq, dtype: int64
# 26     Z996
# 0       L70
# 141     L80
# 140     L20
# 46     L700
# Name: tags, dtype: object
# Objeto destruido...
# Obj deleted
# <AxesSubplot: xlabel='tags', ylabel='freq'>
